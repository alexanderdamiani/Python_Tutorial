# %% [markdown]
# ## Introduction to Data Science
#
# In this notebook we will focus on:
# - pandas DataFrame's attributes and methods
# - reading in a dataset into a pandas DataFrame
# - manipulating the data inside the DataFrame
# - performing simple analysis on the data in the DataFrame

# %% [markdown]
# ## DataFrame attributes and methods

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# just importing this will automatically format the graphs to a more appealing format
# comment this out and generate the plots for the dataframe below to compare to with/without seaborn imported
import seaborn as sns

# this line makes graphs show up in the jupyter notebook, not necessary outside of it
# %matplotlib inline

# %%
# create a DataFrame with dummy data
df = pd.DataFrame(np.random.sample((10,4)))
df
# Out:
#           0         1         2         3
# 0  0.376551  0.869666  0.261762  0.185042
# 1  0.391649  0.152223  0.817694  0.248625
# 2  0.071353  0.331047  0.248060  0.425911
# 3  0.008340  0.366065  0.258307  0.797294
# 4  0.567422  0.012165  0.723156  0.627377
# 5  0.826739  0.072434  0.964393  0.043558
# 6  0.195519  0.097408  0.282522  0.117204
# 7  0.269116  0.699240  0.740805  0.519938
# 8  0.940748  0.738573  0.454361  0.184518
# 9  0.309550  0.958129  0.264314  0.807799

# %%
# assign columns and index of DataFrame
df.columns = ['A', 'B', 'C', 'D']
df.index = range(1,11)
df
# Out:
#            A         B         C         D
# 1   0.376551  0.869666  0.261762  0.185042
# 2   0.391649  0.152223  0.817694  0.248625
# 3   0.071353  0.331047  0.248060  0.425911
# 4   0.008340  0.366065  0.258307  0.797294
# 5   0.567422  0.012165  0.723156  0.627377
# 6   0.826739  0.072434  0.964393  0.043558
# 7   0.195519  0.097408  0.282522  0.117204
# 8   0.269116  0.699240  0.740805  0.519938
# 9   0.940748  0.738573  0.454361  0.184518
# 10  0.309550  0.958129  0.264314  0.807799

# %%
# head and tail methods will give you a snapshot of the top and bottom of the DataFrame
df.head()
# Out:
#           A         B         C         D
# 1  0.376551  0.869666  0.261762  0.185042
# 2  0.391649  0.152223  0.817694  0.248625
# 3  0.071353  0.331047  0.248060  0.425911
# 4  0.008340  0.366065  0.258307  0.797294
# 5  0.567422  0.012165  0.723156  0.627377

# %%
df.tail()
# Out:
#            A         B         C         D
# 6   0.826739  0.072434  0.964393  0.043558
# 7   0.195519  0.097408  0.282522  0.117204
# 8   0.269116  0.699240  0.740805  0.519938
# 9   0.940748  0.738573  0.454361  0.184518
# 10  0.309550  0.958129  0.264314  0.807799

# %%
# Transpose your data
df.T
# Out:
#          1         2         3         4         5         6         7   \
# A  0.376551  0.391649  0.071353  0.008340  0.567422  0.826739  0.195519
# B  0.869666  0.152223  0.331047  0.366065  0.012165  0.072434  0.097408
# C  0.261762  0.817694  0.248060  0.258307  0.723156  0.964393  0.282522
# D  0.185042  0.248625  0.425911  0.797294  0.627377  0.043558  0.117204
#
#          8         9         10
# A  0.269116  0.940748  0.309550
# B  0.699240  0.738573  0.958129
# C  0.740805  0.454361  0.264314
# D  0.519938  0.184518  0.807799

# %%
# sort the DataFrame by a specific column
# inplace=True specifies to change the DataFrame, don't have to do df = df.sort_values...
df.sort_values(by='A', inplace=True)
# can also do multiple columns as df.sort_values(by=['A', 'B'], inplace=True)
df.head()
# Out:
#            A         B         C         D
# 4   0.008340  0.366065  0.258307  0.797294
# 3   0.071353  0.331047  0.248060  0.425911
# 7   0.195519  0.097408  0.282522  0.117204
# 8   0.269116  0.699240  0.740805  0.519938
# 10  0.309550  0.958129  0.264314  0.807799

# %%
# can reset the index so it doesn't appear out of order above
# again inplace=True prevents us from having to assign df = df.reset_index...
# drop=True says to drop the original index, otherwise is added as a column - columns would be ['index', 'A', 'B', 'C', 'D']
df.reset_index(inplace=True, drop=True)
df.head()
# Out:
#           A         B         C         D
# 0  0.008340  0.366065  0.258307  0.797294
# 1  0.071353  0.331047  0.248060  0.425911
# 2  0.195519  0.097408  0.282522  0.117204
# 3  0.269116  0.699240  0.740805  0.519938
# 4  0.309550  0.958129  0.264314  0.807799

# %%
# Selecting data by column
df['A'][:2]
# Out:
# 0    0.008340
# 1    0.071353
# Name: A, dtype: float64

# %%
# Selecting data by index
df.iloc[:2]['A']
# Out:
# 0    0.008340
# 1    0.071353
# Name: A, dtype: float64

# %%
# Working with missing data
df['A'] = [np.nan] + list(range(8)) + [np.nan]
df.head()
# Out:
#      A         B         C         D
# 0  NaN  0.366065  0.258307  0.797294
# 1  0.0  0.331047  0.248060  0.425911
# 2  1.0  0.097408  0.282522  0.117204
# 3  2.0  0.699240  0.740805  0.519938
# 4  3.0  0.958129  0.264314  0.807799

# %%
# fills all NaN values with the first argument you specify across the whole DataFrame
# can specify to only focus on a specific column by doing df['A'].fillna(100, inplace=True)
df.fillna(1, inplace=True)
df.head()
# Out:
#      A         B         C         D
# 0  1.0  0.366065  0.258307  0.797294
# 1  0.0  0.331047  0.248060  0.425911
# 2  1.0  0.097408  0.282522  0.117204
# 3  2.0  0.699240  0.740805  0.519938
# 4  3.0  0.958129  0.264314  0.807799

# %%
# plotting DataFrames
# cumsum function does cummulative sum --> [1,2,3] would become [1, 3, 6]
# drop column 'A' because values are higher than other columns, just for visual purposes (not necessary)
df.drop('A', axis=1, inplace=True)
df = df.cumsum()
df.plot()

# %%
df.plot(kind='bar')

# %%
df.plot(kind='scatter', x='B', y='C')

# %% [markdown]
# ## Data Analysis with pandas DataFrames
#
# We will be working with data on Pokemon for this example.
# We will follow a 3 step process:
# - (1) clean the data
# - (2) visualize the data
# - (3) analyze the results

# %%
df = pd.read_csv('Pokemon.csv')
df.head(20)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                    Ivysaur  Grass  Poison    405  60      62       63
# 2    3                   Venusaur  Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9    7                   Squirtle  Water     NaN    314  44      48       65
# 10   8                  Wartortle  Water     NaN    405  59      63       80
# ...

# %% [markdown]
# ### Clean the Data
#
# Looking at the first 20 rows we can make some observations:
# - (1) the column # is unnecessary so we can remove it
# - (2) in the Name column every name with Mega is preceded by a duplicate of the word after it. We can remove everything before Mega.
# - (3) the Type 2 column has many NaN values. Logical conclusion is to fill the Type 2 column with the Type 1 value for the associated row

# %%
# axis=1 specifies to drop columns and not rows
df.drop('#', axis=1, inplace=True)

# %%
# we first set the type of the column to str with df['Name'].str
# then we apply a function of the str type in python, replace()
# replace() takes two arguments: (1) the string to search for, (2) the string to replace the first string with if its found
df['Name'] = df['Name'].str.replace('.*Mega', 'Mega')

# %%
# fillna of Type 2 with Type 1
df['Type 2'] = df['Type 2'].fillna(df['Type 1'])

# %%
df.head(20)
# Out:
#                 Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0          Bulbasaur  Grass  Poison    318  45      49       49       65
# 1            Ivysaur  Grass  Poison    405  60      62       63       80
# 2           Venusaur  Grass  Poison    525  80      82       83      100
# 3      Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4         Charmander   Fire    Fire    309  39      52       43       60
# 5         Charmeleon   Fire    Fire    405  58      64       58       80
# 6          Charizard   Fire  Flying    534  78      84       78      109
# 7   Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8   Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9           Squirtle  Water   Water    314  44      48       65       50
# 10         Wartortle  Water   Water    405  59      63       80       65
# 11         Blastoise  Water   Water    530  79      83      100       85
# ...

# %%
# check to make sure no other NaN values in our DataFrame
df.isnull().sum()
# Out:
# Name          0
# Type 1        0
# Type 2        0
# Total         0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
# Show a quick summary of the DataFrame to ensure all values look probable
df.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# std    119.96304   25.534669   32.457366   31.183501   32.722294   27.828916
# min    180.00000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    330.00000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
# ### Visualizations of the Data

# %%
# We're going to perform analysis based on the types, so first see what types are available
value_counts = df['Type 1'].value_counts()
value_counts
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
# only plot the top ten values '[:10]', since pie chart gets too crowded
# autopct='%1.1f%%' is an argument passed to display percentages inside of each pie slice
value_counts[:10].plot(kind='pie', autopct='%1.1f%%')

# %%
fig, ax = plt.subplots(1,1,figsize=(20,10))

sns.barplot(value_counts.index, value_counts.values, ax=ax)

ax.tick_params(labelsize=18, direction='out', pad=15)
ax.set_xlabel('Type 1', weight='bold', size='20', labelpad=15)
ax.set_ylabel('Count', weight='bold', size='20', labelpad=15)
ax.set_title('Count of Pokemons (per type 1)',  size='26', weight='bold', y=1.05)

# %%
g = (sns.FacetGrid(data=df, col='Type 1',hue='Type 2',
                   col_wrap=3, size=4)
        .map(sns.countplot, 'Type 2', order=df["Type 2"].unique())
        .set_axis_labels('Type 2', 'Count')
        .set(xticklabels=[])
        .add_legend()
        .fig
        .suptitle('Second type count of Pokemons given the first one', 
                  weight='bold', y=1.05))

# %% [markdown]
# We see psychic and grass each compose a large portion of the number of types. So we'll perform our analysis on them.

# %%
# Filter out rows where Type 1 or Type 2 is Psychic, or Grass
df_psychic = df[(df['Type 1'] == 'Psychic') | (df['Type 2'] == 'Psychic')]
df_grass = df[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Grass')]

# %%
# plot the two selected types on the same graph
# assign the first plot to an object 'ax' so we can pass it as a parameter to the second DataFrame plot, 
# so they'll plot on the same graph

# label argument is necessary for the ax.legend() to know what labels to assign for each dataset
ax = df_psychic.plot(kind='scatter', x='Attack', y='Defense', color='purple', label='Psychic', 
                     title='Grass vs. Psychic attack and defense')
df_grass.plot(kind='scatter', x='Attack', y='Defense', color='green', label='Grass', ax=ax)
ax.legend()

# %%
corr_mtx = df[['Attack', 'Defense', 'Speed', 'HP']].corr()
sns.heatmap(corr_mtx,annot=True)

# %% [markdown]
# ### Data Analysis

# %% [markdown]
# We can draw a few conclusions from the Grass vs Psychic plot above.
# - psychic type pokemon have a larger range of possible attack and defense values
# - psychic type pokemon have a larger distribution of attack and defense combinations than grass types
# - even with the previous two points, we see a lot of overlap between the psychic and grass type pokemon attack and defense pairings
# - if we needed to chose a pokemon purely based on this information, the answer isn't clear cut
#     - psychic pokemon have higher possible attack and defense combinations, but also more lower combinations (especially high attack and low defense)
#     - whether we are prioritizing attack (likely chose psychic), or defense (likely chose grass) would decide our choice of pokemon
#
# Regarding the correlation matrix above, we can draw the following conclusions:
# - Attack has the highest correlation to all other attributes, while spped has the lowest correlation among attributes.
# - Defense and HP are also quite low correlation with other attributes.
